# %%
import tweepy
import csv
import pandas as pd
####input your credentials here
consumer_key = '48YhYe1JnumkxKx7T8c5O90kC'
consumer_secret = 'KCM7HZwpYW21YFSXutwDr0OIspTDZIPQK3ovHGTuQS8aYBBBnQ'
access_token = '1378639340885012482-9CXDhexLwoJzIuDCRBzHhwLDsLSFw1'
access_token_secret = 'ozX4rypgjCZigmZp5MAF4UpDBQM5k4EhdNtTGAK87E34V'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
fields=['Date','Tweet']
csvfile=open('vaccine2.csv','w')
csvwriter=csv.writer(csvfile)

# %%
# list=['#COVID19','#CovidIndia','#Vaccinefor18plus','#coronavirusPandemic','#Vaccine','#Getvaccinateed','#Vacccineworks','#covidvaccine','#covidvaccinesideeffect','#covidIndiaHelp']
for tweet in tweepy.Cursor(api.search,q= '#vaccine',lang='en'
                           ,since="2021-01-16").items():
    csvwriter.writerow(fields)
    csvwriter.writerow([tweet.created_at,tweet.text.encode('utf-8')])
    print(tweet.created_at,tweet.text)
# Out:
# 2021-05-11 14:31:25 RT @kamarulbahrin: Our neighbour vaccinating 600,000 #Teachers. God bless MoE #Thailand #vaccine #COVID19
# 2021-05-11 14:31:25 Healthcare Insights pros, we are hooking you up with the info-- What is most compelling for patients: Physicians? D… https://t.co/crdHXzA5MT
# 2021-05-11 14:31:22 RT @BharatBiotech: COVAXIN® has been directly supplied to 18 states since May 1st.
# Unflinching in our efforts, we will continue the steady…
# 2021-05-11 14:31:21 RT @BharatBiotech: COVAXIN® has been directly supplied to 18 states since May 1st.
# Unflinching in our efforts, we will continue the steady…
# 2021-05-11 14:31:18 RT @BharatBiotech: COVAXIN® has been directly supplied to 18 states since May 1st.
# Unflinching in our efforts, we will continue the steady…
# 2021-05-11 14:31:16 RT @BharatBiotech: COVAXIN® has been directly supplied to 18 states since May 1st.
# Unflinching in our efforts, we will continue the steady…
# ...
